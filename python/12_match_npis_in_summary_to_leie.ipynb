# %%
import psycopg2
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

# %matplotlib inline
sns.set(style="white")

# %%
## connect to database
con = psycopg2.connect("dbname='doctordb' user='cathy'")

# %%
## excluded providers that are in summary
## (join on leie.NPI=summary.npi)
## select exclusion dates > 2015-01-01 so that payment claims reflect full 2014 year
q = """SELECT summary.npi
            , summary.provider_type
            , summary.nppes_provider_state
            , leie.EXCLDATE as exclusion_date
            FROM summary
                JOIN leie 
                ON (leie.NPI = summary.npi)
            WHERE leie.EXCLDATE > '2015-01-01';"""
providers = pd.read_sql_query(q, con=con)

# %%
providers.shape
# Out:
# (199, 4)

# %%
providers.head()
# Out:
#           npi           provider_type nppes_provider_state exclusion_date
# 0  1972607398       Internal Medicine                   FL     2016-09-20
# 1  1487765467   Clinical Psychologist                   OH     2016-09-20
# 2  1861487308         Family Practice                   FL     2016-08-18
# 3  1811282098       Internal Medicine                   TX     2016-08-18
# 4  1689986945  Occupational therapist                   NY     2016-08-18

# %%
## how many providers per provider type?
(providers.groupby('provider_type')['npi'].
        count().
        reset_index().
        rename(columns={'npi':'count'}).
        sort_values('count', ascending=False))
# Out:
#                            provider_type  count
# 16                     Internal Medicine     45
# 10                       Family Practice     25
# 38                            Psychiatry     20
# 12                      General Practice     12
# 5                           Chiropractic      8
# 23                    Nurse Practitioner      8
# 36                              Podiatry      7
# 33  Physical Medicine and Rehabilitation      7
# 8                            Dermatology      6
# 35                   Physician Assistant      5
# 24                 Obstetrics/Gynecology      4
# 20                             Neurology      3
# 28                    Orthopedic Surgery      3
# 18       Licensed Clinical Social Worker      3
# 17        Interventional Pain Management      3
# 29     Osteopathic Manipulative Medicine      3
# 9                     Emergency Medicine      3
# 39                     Pulmonary Disease      3
# 34                    Physical Therapist      2
# 1    Audiologist (billing independently)      2
# 21                          Neurosurgery      2
# 7                  Clinical Psychologist      2
# 25                Occupational therapist      2
# 26                         Ophthalmology      2
# 27                             Optometry      2
# 15                   Hematology/Oncology      2
# 30                        Otolaryngology      1
# 32                    Pediatric Medicine      1
# 31                             Pathology      1
# 37                        Portable X-ray      1
# 0                         Anesthesiology      1
# 22                      Nuclear Medicine      1
# 19                      Medical Oncology      1
# 14                    Geriatric Medicine      1
# 13                       General Surgery      1
# 11                      Gastroenterology      1
# 6                    Clinical Laboratory      1
# 4    Certified Clinical Nurse Specialist      1
# 3                             Cardiology      1
# 2                                   CRNA      1
# 40                               Urology      1

# %%
## how many providers per state?
(providers.groupby('nppes_provider_state')['npi'].
        count().
        reset_index().
        rename(columns={'npi':'count'}).
        sort_values('count', ascending=False))
# Out:
#    nppes_provider_state  count
# 10                   IL     25
# 2                    CA     20
# 6                    FL     14
# 22                   NY     13
# 16                   MI     13
# 19                   NJ     13
# 28                   TX      8
# 14                   MD      7
# 27                   TN      7
# 11                   IN      7
# 0                    AL      7
# 30                   VA      7
# 12                   KY      6
# 20                   NM      6
# 31                   WA      5
# 25                   PA      4
# 4                    CT      4
# 32                   WI      4
# 29                   UT      3
# 17                   MO      3
# 8                    IA      3
# 7                    GA      3
# 21                   NV      2
# 23                   OH      2
# 26                   PR      2
# 13                   LA      2
# 3                    CO      2
# 18                   NC      1
# 1                    AR      1
# 24                   OK      1
# 15                   ME      1
# 9                    ID      1
# 5                    DE      1
# 33                   WV      1

# %%
providers[providers.provider_type=='Orthopedic Surgery']
# Out:
#             npi       provider_type nppes_provider_state exclusion_date
# 35   1174693949  Orthopedic Surgery                   NY     2016-06-20
# 153  1427029925  Orthopedic Surgery                   MI     2015-07-20
# 193  1316151525  Orthopedic Surgery                   NY     2015-02-19

# %%
providers[providers.provider_type=='Medical Oncology']
# Out:
#             npi     provider_type nppes_provider_state exclusion_date
# 151  1093779456  Medical Oncology                   TN     2015-08-20

# %%
providers[providers.provider_type=='Hematology/Oncology']
# Out:
#             npi        provider_type nppes_provider_state exclusion_date
# 103  1871596098  Hematology/Oncology                   FL     2015-12-20
# 162  1285673012  Hematology/Oncology                   TX     2015-06-18

# %%
providers[providers.provider_type=='Internal Medicine'].head()
# Out:
#            npi      provider_type nppes_provider_state exclusion_date
# 0   1972607398  Internal Medicine                   FL     2016-09-20
# 3   1811282098  Internal Medicine                   TX     2016-08-18
# 8   1528051307  Internal Medicine                   PA     2016-08-18
# 23  1225082886  Internal Medicine                   PA     2016-07-20
# 29  1689756827  Internal Medicine                   NY     2016-06-20

# %% [markdown]
# ## `provider_type` = Internal Medicine has the most cases of fraud (45)
# How many of these internal medicine providers have claims data (i.e. in payments table) as well?

# %%
internal_med_npi = tuple(providers.loc[providers.provider_type=='Internal Medicine','npi'])

# %%
internal_med_npi[:5]
# Out:
# ('1972607398', '1811282098', '1528051307', '1225082886', '1689756827')

# %%
## excluded providers that are in summary
## (join on leie.NPI=summary.npi)
## select exclusion dates > 2015-01-01 so that payment claims reflect full 2014 year
q = """SELECT * FROM payments WHERE npi IN {0};""".format(internal_med_npi)
payments = pd.read_sql_query(q, con=con)

# %%
payments.shape
# Out:
# (527, 26)

# %%
payments.drop_duplicates(['npi']).shape
# Out:
# (44, 26)

# %% [markdown]
# 44 internal medicine providers made claims in payments table during 2014.
#
# 1 fraudulent provider is in the summary table but not in payments.

# %%
## number of rows / distinct hcpcs_code claims made per provider
payments.groupby('npi')['npi'].count()
# Out:
# npi
# 1043238421    42
# 1043257744    21
# 1053458018    10
# 1073808945     5
# 1093851164    13
# 1124016480    29
# 1134139884    14
# 1174543342     8
# 1184786196     2
# 1225011612     8
# 1225082886    13
# 1235133794     5
# 1245253012     1
# 1245279645     7
# 1306830021     9
# 1316935406    15
# 1336203603    21
# 1396906160    12
# 1417967647     8
# 1427071059     8
# 1427090562    30
# 1427098268    12
# 1497737266     2
# 1528051307     2
# 1528111341    13
# 1558364166     9
# 1558405647     3
# 1568410496    21
# 1568494169     1
# 1578615316     9
# 1588694343    31
# 1609829985    21
# 1679549513     2
# 1689756827     2
# 1770656506    15
# 1811282098     3
# 1831121979     9
# 1841206307     8
# 1871571406    36
# 1891722237    12
# 1912032780     2
# 1922032770    13
# 1962461640     3
# 1972607398    17
# Name: npi, dtype: int64

# %%
payments.drop_duplicates('npi')[['npi','nppes_provider_last_org_name','provider_type']]
# Out:
#             npi nppes_provider_last_org_name      provider_type
# 0    1043238421                      HUSSAIN  Internal Medicine
# 42   1043257744                      DE LUCA  Internal Medicine
# 63   1053458018                       APONTE  Internal Medicine
# 73   1073808945                        HOGAN  Internal Medicine
# 78   1093851164                       LUCERO  Internal Medicine
# 91   1124016480                        HAMER  Internal Medicine
# 120  1134139884                        BRUCE  Internal Medicine
# 134  1174543342                      WHITEUS  Internal Medicine
# 142  1184786196                     JAKIMIEC  Internal Medicine
# 144  1225011612                        NDOLO  Internal Medicine
# 152  1225082886                         WEAN  Internal Medicine
# 165  1235133794                      RAMAIAH  Internal Medicine
# 170  1245253012                      STANGER  Internal Medicine
# 171  1245279645                     LODEWICK  Internal Medicine
# 178  1306830021                       HEDVAT  Internal Medicine
# 187  1316935406                       SADLER  Internal Medicine
# 202  1336203603                       DANIEL  Internal Medicine
# 223  1396906160                      DOUGLAS  Internal Medicine
# 235  1417967647                     GOYZUETA  Internal Medicine
# 243  1427071059                       BASHIR  Internal Medicine
# 251  1427090562                  BLANKENSHIP  Internal Medicine
# 281  1427098268                     DESIMONE  Internal Medicine
# 293  1497737266                       KROUPA  Internal Medicine
# 295  1528051307                         WAIT  Internal Medicine
# 297  1528111341                        LODHI  Internal Medicine
# 310  1558364166                     LAJEWSKI  Internal Medicine
# 319  1558405647                      IBRAHIM  Internal Medicine
# 322  1568410496                     KULDANEK  Internal Medicine
# 343  1568494169                    ROSENBERG  Internal Medicine
# 344  1578615316                      RUSSELL  Internal Medicine
# 353  1588694343                          MAY  Internal Medicine
# 384  1609829985                       VITALI  Internal Medicine
# 405  1679549513                  DEBENEDETTO  Internal Medicine
# 407  1689756827                         LOWE  Internal Medicine
# 409  1770656506                        CHUNG  Internal Medicine
# 424  1811282098                       SHEIKH  Internal Medicine
# 427  1831121979                     KATSETOS  Internal Medicine
# 436  1841206307                         ROSS  Internal Medicine
# 444  1871571406                        ASWAD  Internal Medicine
# 480  1891722237                    CALABRESE  Internal Medicine
# 492  1912032780                    AHLUWALIA  Internal Medicine
# 494  1922032770                     DELPIANO  Internal Medicine
# 507  1962461640                        KINER  Internal Medicine
# 510  1972607398                      DELISMA  Internal Medicine

# %%
## write out to csv the npi s of the 44 internal medicine npi fraudsters
(pd.DataFrame(payments.drop_duplicates('npi')['npi'])
.to_csv('internal_medicine_npi_fraud.csv', index=False))
